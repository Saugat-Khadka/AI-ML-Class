# %%
import pandas as pd

# %%
path = "Data\Titanic-Dataset.csv"

df = pd.read_csv(path)
df.head(10)

# %%
df.head(5)

# %%
df.tail(5)

# %%
df.info()

# %%
df.describe()

# %%
df[["Survived", "Fare"]].describe()
