# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# For Nepali to English translation, we'll use another general multilingual Opus-MT model.

tokenizer_mul_en = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-mul-en")

model_mul_en = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-mul-en")


nepali_text_en = "नमस्ते, हजुरलाई आज कस्तो छ? मलाई आशा छ कि तपाईले हगिङ फेस मोडलहरू प्रयोग गरेर राम्रो समय बिताउनुहुनेछ!"


# Prepare input for the translation model

inputs_mul_en = tokenizer_mul_en(nepali_text_en, return_tensors="pt")

translated_ids_mul_en = model_mul_en.generate(inputs_mul_en.input_ids)

english_translation_ne = tokenizer_mul_en.decode(translated_ids_mul_en[0],
skip_special_tokens=True)


print(f"Original Nepali: {nepali_text_en}")

print(f"Translated English: {english_translation_ne}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
#       2
#       3 # For Nepali to English translation, we'll use another general multilingual Opus-MT model.
#       4
# ----> 5 tokenizer_mul_en = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-mul-en")
#       6
#       7 model_mul_en = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-mul-en")
#       8
#
# File c:\Users\ksaug\OneDrive\Desktop\Day\Day 13\.venv\Lib\site-packages\transformers\models\auto\tokenization_auto.py:1149, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1147             return tokenizer_class_py.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1148         else:
# -> 1149             raise ValueError(
#    1150                 "This tokenizer cannot be instantiated. Please make sure you have `sentencepiece` installed "
#    1151                 "in order to use this tokenizer."
#    1152             )
#    1154 raise ValueError(
#    1155     f"Unrecognized configuration class {config.__class__} to build an AutoTokenizer.\n"
#    1156     f"Model type should be one of {', '.join(c.__name__ for c in TOKENIZER_MAPPING)}."
#    1157 )
#
# ValueError: This tokenizer cannot be instantiated. Please make sure you have `sentencepiece` installed in order to use this tokenizer.
