# %%
from transformers import pipeline

# %%
model = pipeline(
    "sentiment-analysis",
    model="distilbert/distilbert-base-uncased-finetuned-sst-2-english"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model = pipeline(
#       2     "sentiment-analysis",
#       3     model="distilbert/distilbert-base-uncased-finetuned-sst-2-english"
#       4 )
#
# File c:\Users\ksaug\OneDrive\Desktop\Day\Day 13\.venv\Lib\site-packages\transformers\pipelines\__init__.py:1024, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1019         raise ValueError(
#    1020             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1021             " arguments might conflict, use only one.)"
#    1022         )
#    1023 if dtype is not None:
# -> 1024     if isinstance(dtype, str) and hasattr(torch, dtype):
#    1025         dtype = getattr(torch, dtype)
#    1026     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined

# %%
model("I love using AI in DevOps")

# %%
import torch
import transformers

print(torch.__file__)
print(transformers.__file__)

from transformers import pipeline
classifier = pipeline("sentiment-analysis")

# %%
import transformers
print(transformers.__version__)
